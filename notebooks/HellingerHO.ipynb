# %% [markdown]
# # Numerical analysis of ergodicity of 1D potentials thermostatted using the DD algorithm

# %% [markdown]
# ## Harmonic Oscillator

# %%
using PyPlot
using PyCall
@pyimport matplotlib as mpl
mpl.style[:use]("classic")

# %%
filename = "hellig3cHO"
data = readdlm("../poincaredata/sectionsandtrajectories/$filename");

# %%
t = data[:,1]
h = data[:,2];

# %%
plot(t, h, "o-", ms = 5.0)
plt[:xlabel](L"t")
plt[:ylabel](L"D_H")
plt[:ticklabel_format](style="sci", axis="x" , scilimits = (0,0))
plt[:savefig]("../plots/$filename.pdf")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f0a9ce7a590>)
