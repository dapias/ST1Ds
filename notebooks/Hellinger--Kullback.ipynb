# %% [markdown]
# # Numerical analysis of ergodicity of 1D potentials thermostatted using the DD algorithm

# %%
using PyPlot
using PyCall
@pyimport matplotlib as mpl
mpl.style[:use]("classic")

# %%
filename = "integralig3cHO"
data = readdlm("../hellinger/$filename");

# %%
t = data[:,1]
h = data[:,2];

# %%
filename = "integralX4v7MH"
data = readdlm("../hellinger/$filename");
t1 = data[:,1]
h1 = data[:,2];

# %%
filename = "integral0F7YQP"
data = readdlm("../hellinger/$filename");
t2 = data[:,1]
h2 = data[:,2];

# %%
fig = plt[:figure]()
ax = fig[:add_subplot](1,1,1)

#ax[:set_xscale]("log")
#ax[:set_yscale]("log")

a = ax[:plot](t, h, "o--", ms = 5.0, label = "Harmonic" )
b = ax[:plot](t, h2, "o--", ms = 5.0, label = "Quartic" )
c = ax[:plot](t, h1, "o--", ms = 5.0, label = "Mexican" )


#ax[:set_xlim](10^4.7,10^6.2)
#ax[:set_ylim](10^-1.4, 10^-0.6)
ax[:set_xlabel](L"t")
ax[:set_ylabel](L"D_H")
ax[:ticklabel_format](style="sci", axis="x" , scilimits = (0,0))
handles, labels = ax[:get_legend_handles_labels]()
ax[:legend](handles, labels)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb78686c90>)
# PyObject <matplotlib.legend.Legend object at 0x7fcb78654850>

# %%
fig = plt[:figure]()
ax = fig[:add_subplot](1,1,1)

ax[:set_xscale]("log")
ax[:set_yscale]("log")

a = ax[:plot](t, h, "o--", ms = 5.0, label = "Harmonic" )
b = ax[:plot](t, h2, "o--", ms = 5.0, label = "Quartic" )
c = ax[:plot](t, h1, "o--", ms = 5.0, label = "Mexican" )


ax[:set_xlim](10^4.7,10^6.2)
ax[:set_ylim](10^-2.4, 10^-1.1)
ax[:set_xlabel](L"t")
ax[:set_ylabel](L"D_H")
#ax[:ticklabel_format](style="sci", axis="x" , scilimits = (0,0))
handles, labels = ax[:get_legend_handles_labels]()
ax[:legend](handles, labels)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb77ff0850>)
# PyObject <matplotlib.legend.Legend object at 0x7fcb77afea50>

# %% [markdown]
# ### Kullback Leibler distance

# %%
filename = "integralig3cHO"
data = readdlm("../kullback/$filename");

# %%
t = data[:,1]
h = data[:,2];

# %%
filename = "integralX4v7MH"
data = readdlm("../kullback/$filename");
t1 = data[:,1]
h1 = data[:,2];

# %%
filename = "integral0F7YQP"
data = readdlm("../kullback/$filename");
t2 = data[:,1]
h2 = data[:,2];

# %%
fig = plt[:figure]()
ax = fig[:add_subplot](1,1,1)

#ax[:set_xscale]("log")
#ax[:set_yscale]("log")

a = ax[:plot](t, h, "o--", ms = 5.0, label = "Harmonic" )
b = ax[:plot](t, h2, "o--", ms = 5.0, label = "Quartic" )
c = ax[:plot](t, h1, "o--", ms = 5.0, label = "Mexican" )


#ax[:set_xlim](10^4.7,10^6.2)
#ax[:set_ylim](10^-1.4, 10^-0.6)
ax[:set_xlabel](L"t")
ax[:set_ylabel](L"D_H")
ax[:ticklabel_format](style="sci", axis="x" , scilimits = (0,0))
handles, labels = ax[:get_legend_handles_labels]()
ax[:legend](handles, labels)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb77e12250>)
# PyObject <matplotlib.legend.Legend object at 0x7fcb7858a790>

# %%
fig = plt[:figure]()
ax = fig[:add_subplot](1,1,1)

ax[:set_xscale]("log")
ax[:set_yscale]("log")

a = ax[:plot](t, h, "o--", ms = 5.0, label = "Harmonic" )
b = ax[:plot](t, h2, "o--", ms = 5.0, label = "Quartic" )
c = ax[:plot](t, h1, "o--", ms = 5.0, label = "Mexican" )


ax[:set_xlim](10^4.7,10^6.2)
ax[:set_ylim](10^-2.4, 10^-1.1)
ax[:set_xlabel](L"t")
ax[:set_ylabel](L"D_H")
#ax[:ticklabel_format](style="sci", axis="x" , scilimits = (0,0))
handles, labels = ax[:get_legend_handles_labels]()
ax[:legend](handles, labels)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fcb77787790>)
# PyObject <matplotlib.legend.Legend object at 0x7fcb77703a10>
